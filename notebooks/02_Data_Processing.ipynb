# %% [markdown]
# <center><h1><font size=6> Data Processing </h1></center>

# %% [markdown]
# This notebook takes the raw EPL match data that was scraped in notebook 01 and processes the data to make sure it is in a clean and consistent format. More machine learning specific processing, filtering and cleaning will need to be done at the feature engineering stage, but this notebook carries out some basic functionality, including:
# * Cleaning up column names and descriptions
# * Cleaning column types
# * Ensuring team names are consistent across the dataset

# %% [markdown]
# ### Load libraries and setup notebook configuration

# %%
# import packages
import pandas as pd 
import numpy as np
import os
from pathlib import Path
from datetime import datetime


# set pandas configurations
pd.set_option("display.precision", 2) # display to 1 decimpal place
pd.set_option("display.max.columns", None) # display all columns so we can view the whole dataset


# set directories
os.chdir('..') # change current working directory to the parent directory to help access files/directories at a higher level
DATAPATH = Path(r'data') # set data path


# import from source directory
from src import constants

# %% [markdown]
# ### Load data from local data file

# %%
# load EPL match data
matches_raw = pd.read_csv(f"{DATAPATH}/raw/matches_raw.csv")
matches_raw.head(5)
# Out:
#    Unnamed: 0        Date   Time              Comp                Round  Day
# 0           0  2022-07-30  17:00  Community Shield  FA Community Shield  Sat  \
# 1           1  2022-08-07  16:30    Premier League          Matchweek 1  Sun
# 2           2  2022-08-13  15:00    Premier League          Matchweek 2  Sat
# 3           3  2022-08-21  16:30    Premier League          Matchweek 3  Sun
# 4           4  2022-08-27  15:00    Premier League          Matchweek 4  Sat
#
#      Venue Result GF GA        Opponent   xG  xGA  Poss  Attendance
# 0  Neutral      L  1  3       Liverpool  NaN  NaN  57.0         NaN  \
# 1     Away      W  2  0        West Ham  2.2  0.5  75.0     62443.0
# 2     Home      W  4  0     Bournemouth  1.7  0.1  67.0     53453.0
# 3     Away      D  3  3   Newcastle Utd  2.1  1.8  69.0     52258.0
# 4     Home      W  4  2  Crystal Palace  2.2  0.1  74.0     53112.0
#
#            Captain Formation         Referee  Match Report Notes  season
# 0       Rúben Dias     4-3-3    Craig Pawson  Match Report   NaN    2022  \
# 1   İlkay Gündoğan     4-3-3  Michael Oliver  Match Report   NaN    2022
# 2   İlkay Gündoğan   4-2-3-1     David Coote  Match Report   NaN    2022
# 3   İlkay Gündoğan     4-3-3  Jarred Gillett  Match Report   NaN    2022
# 4  Kevin De Bruyne   4-2-3-1  Darren England  Match Report   NaN    2022
#
#               team date_donwloaded
# 0  Manchester City      2023-06-19
# 1  Manchester City      2023-06-19
# 2  Manchester City      2023-06-19
# 3  Manchester City      2023-06-19
# 4  Manchester City      2023-06-19

# %% [markdown]
# ### Clean data

# %%
matches_clean = matches_raw.iloc[:, 1:] # drop first column as it is an empty unnamed index


# clean column names
matches_clean.columns = map(str.lower, matches_clean.columns) # make columns lower case
matches_clean.columns = matches_clean.columns.str.replace(' ', '_') # replace spaces in column names


# clean column types
matches_clean['date'] = pd.to_datetime(matches_clean['date']) # convert date into datetime object
matches_clean['time'] = pd.to_datetime(matches_clean['time'], format='%H:%M').dt.time # convert date into time object
#matches_clean['date_downloaded'] = pd.to_datetime(matches_clean['date_downloaded']) # convert date downloaded into datetime object
matches_clean['gf'] = pd.to_numeric(matches_clean['gf'], errors='coerce', downcast='integer') # convert goals for to numeric
matches_clean['ga'] = pd.to_numeric(matches_clean['gf'], errors='coerce', downcast='integer') # convert goals against to numeric

# %%
matches_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5732 entries, 0 to 5731
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             5732 non-null   datetime64[ns]
#  1   time             5732 non-null   object
#  2   comp             5732 non-null   object
#  3   round            5732 non-null   object
#  4   day              5732 non-null   object
#  5   venue            5732 non-null   object
#  6   result           5732 non-null   object
#  7   gf               5637 non-null   float64
#  8   ga               5637 non-null   float64
#  9   opponent         5732 non-null   object
#  10  xg               4996 non-null   float64
#  11  xga              4996 non-null   float64
#  12  poss             5710 non-null   float64
#  13  attendance       4639 non-null   float64
#  14  captain          5730 non-null   object
#  15  formation        5730 non-null   object
#  16  referee          5731 non-null   object
#  17  match_report     5732 non-null   object
#  18  notes            351 non-null    object
#  19  season           5732 non-null   int64
#  20  team             5732 non-null   object
#  21  date_donwloaded  5732 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(1), object(14)
# memory usage: 985.3+ KB

# %% [markdown]
# ### Create a unique game ID for each game

# %%
# create an ID based on the date, venue, team and opponent
matches_clean['unique_match_id'] = (matches_clean['date'].dt.strftime("%Y%m%d")
                                    + pd.factorize(matches_clean['venue'])[0].astype(str)
                                    + pd.factorize(matches_clean['team'])[0].astype(str) 
                                    + pd.factorize(matches_clean['opponent'])[0].astype(str))
matches_clean = matches_clean[['unique_match_id'] + [col for col in matches_clean.columns if col != 'unique_match_id']] # make ID first column
# Out:
#      unique_match_id       date      time              comp
# 0        20220730000 2022-07-30  17:00:00  Community Shield  \
# 1        20220807101 2022-08-07  16:30:00    Premier League
# 2        20220813202 2022-08-13  15:00:00    Premier League
# 3        20220821103 2022-08-21  16:30:00    Premier League
# 4        20220827204 2022-08-27  15:00:00    Premier League
# ...              ...        ...       ...               ...
# 5727   2018041512310 2018-04-15  16:00:00    Premier League
# 5728    201804212230 2018-04-21  12:30:00    Premier League
# 5729    201804281233 2018-04-28  15:00:00    Premier League
# 5730   2018050522320 2018-05-05  15:00:00    Premier League
# 5731    201805131234 2018-05-13  15:00:00    Premier League
#
#                     round  day    venue result   gf   ga        opponent   xg
# 0     FA Community Shield  Sat  Neutral      L  1.0  1.0       Liverpool  NaN  \
# 1             Matchweek 1  Sun     Away      W  2.0  2.0        West Ham  2.2
# 2             Matchweek 2  Sat     Home      W  4.0  4.0     Bournemouth  1.7
# 3             Matchweek 3  Sun     Away      D  3.0  3.0   Newcastle Utd  2.1
# 4             Matchweek 4  Sat     Home      W  4.0  4.0  Crystal Palace  2.2
# ...                   ...  ...      ...    ...  ...  ...             ...  ...
# 5727         Matchweek 34  Sun     Away      W  1.0  1.0  Manchester Utd  0.7
# 5728         Matchweek 35  Sat     Home      D  2.0  2.0       Liverpool  1.3
# 5729         Matchweek 36  Sat     Away      W  1.0  1.0   Newcastle Utd  0.7
# 5730         Matchweek 37  Sat     Home      W  1.0  1.0       Tottenham  1.6
# 5731         Matchweek 38  Sun     Away      L  0.0  0.0  Crystal Palace  0.2
#
#       xga  poss  attendance          captain formation         referee
# 0     NaN  57.0         NaN       Rúben Dias     4-3-3    Craig Pawson  \
# 1     0.5  75.0     62443.0   İlkay Gündoğan     4-3-3  Michael Oliver
# 2     0.1  67.0     53453.0   İlkay Gündoğan   4-2-3-1     David Coote
# 3     1.8  69.0     52258.0   İlkay Gündoğan     4-3-3  Jarred Gillett
# 4     0.1  74.0     53112.0  Kevin De Bruyne   4-2-3-1  Darren England
# ...   ...   ...         ...              ...       ...             ...
# 5727  0.7  30.0     75095.0      Chris Brunt   4-4-1-1    Paul Tierney
# 5728  1.3  39.0     24520.0      Chris Brunt   4-4-1-1  Stuart Attwell
# 5729  1.8  38.0     52283.0      Chris Brunt   4-4-1-1     David Coote
# 5730  1.2  26.0     23685.0      Chris Brunt   4-4-1-1      Mike Jones
# 5731  2.2  41.0     25357.0      Chris Brunt   4-4-1-1   Jonathan Moss
#
#       match_report notes  season                  team date_donwloaded
# 0     Match Report   NaN    2022       Manchester City      2023-06-19
# 1     Match Report   NaN    2022       Manchester City      2023-06-19
# 2     Match Report   NaN    2022       Manchester City      2023-06-19
# 3     Match Report   NaN    2022       Manchester City      2023-06-19
# 4     Match Report   NaN    2022       Manchester City      2023-06-19
# ...            ...   ...     ...                   ...             ...
# 5727  Match Report   NaN    2017  West Bromwich Albion      2023-06-19
# 5728  Match Report   NaN    2017  West Bromwich Albion      2023-06-19
# 5729  Match Report   NaN    2017  West Bromwich Albion      2023-06-19
# 5730  Match Report   NaN    2017  West Bromwich Albion      2023-06-19
# 5731  Match Report   NaN    2017  West Bromwich Albion      2023-06-19
#
# [5732 rows x 23 columns]

# %% [markdown]
# ### Cleaning team names
#
# One issue we have with the data in its raw format is that the team names are different in the 'team' and 'opponent' column, which makes it dificult to map across data in future. So let's create a mapping to ensure all our team names are consistent.

# %%
# collect team names
teams = np.sort(matches_clean.team.unique())


# collect opponent names (just premier league)
pl_matches = matches_clean[matches_clean['comp'] == "Premier League"] # filter to just contain PL opponents otherwise we get european and cup game opponents as well
opponents = np.sort(pl_matches.opponent.unique())


# find the index points within each list where the names are not equal
unequal_indexes = [i for i, (x, y) in enumerate(zip(teams, opponents)) if x != y]

for index in unequal_indexes:
    print(f"Team name [{index}]: {teams[index]}, Opponenent name [{index}]: {opponents[index]}")
# Out:
# Team name [4]: Brighton and Hove Albion, Opponenent name [4]: Brighton
# Team name [11]: Huddersfield Town, Opponenent name [11]: Huddersfield
# Team name [16]: Manchester United, Opponenent name [16]: Manchester Utd
# Team name [17]: Newcastle United, Opponenent name [17]: Newcastle Utd
# Team name [19]: Nottingham Forest, Opponenent name [19]: Nott'ham Forest
# Team name [20]: Sheffield United, Opponenent name [20]: Sheffield Utd
# Team name [24]: Tottenham Hotspur, Opponenent name [24]: Tottenham
# Team name [26]: West Bromwich Albion, Opponenent name [26]: West Brom
# Team name [27]: West Ham United, Opponenent name [27]: West Ham
# Team name [28]: Wolverhampton Wanderers, Opponenent name [28]: Wolves

# %%
# map the opponent team names to the team names to ensure consistency
team_mapping = dict(zip(opponents, teams)) # create a dictionary mapping each unique opponent name to the team name
matches_clean['opponent'] = matches_clean['opponent'].map(lambda x: team_mapping.get(x, x)) # map to new names but leave original name if no mapping found (e.g., champions league games)

# %%
matches_clean.head()
# Out:
#         date      time              comp                round  day    venue
# 0 2022-07-30  17:00:00  Community Shield  FA Community Shield  Sat  Neutral  \
# 1 2022-08-07  16:30:00    Premier League          Matchweek 1  Sun     Away
# 2 2022-08-13  15:00:00    Premier League          Matchweek 2  Sat     Home
# 3 2022-08-21  16:30:00    Premier League          Matchweek 3  Sun     Away
# 4 2022-08-27  15:00:00    Premier League          Matchweek 4  Sat     Home
#
#   result   gf   ga          opponent   xg  xga  poss  attendance
# 0      L  1.0  1.0         Liverpool  NaN  NaN  57.0         NaN  \
# 1      W  2.0  2.0   West Ham United  2.2  0.5  75.0     62443.0
# 2      W  4.0  4.0       Bournemouth  1.7  0.1  67.0     53453.0
# 3      D  3.0  3.0  Newcastle United  2.1  1.8  69.0     52258.0
# 4      W  4.0  4.0    Crystal Palace  2.2  0.1  74.0     53112.0
#
#            captain formation         referee  match_report notes  season
# 0       Rúben Dias     4-3-3    Craig Pawson  Match Report   NaN    2022  \
# 1   İlkay Gündoğan     4-3-3  Michael Oliver  Match Report   NaN    2022
# 2   İlkay Gündoğan   4-2-3-1     David Coote  Match Report   NaN    2022
# 3   İlkay Gündoğan     4-3-3  Jarred Gillett  Match Report   NaN    2022
# 4  Kevin De Bruyne   4-2-3-1  Darren England  Match Report   NaN    2022
#
#               team date_donwloaded   opponent_mapped
# 0  Manchester City      2023-06-19         Liverpool
# 1  Manchester City      2023-06-19   West Ham United
# 2  Manchester City      2023-06-19       Bournemouth
# 3  Manchester City      2023-06-19  Newcastle United
# 4  Manchester City      2023-06-19    Crystal Palace

# %%
# save clean data in processed data file
matches_clean.to_csv(f"{DATAPATH}/processed/matches_processed.csv")
